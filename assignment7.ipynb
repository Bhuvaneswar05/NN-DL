# %%
# Simple CNN model for CIFAR-10
import numpy
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
#from keras import backend as K
#K.set_image_dim_ordering('th')

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]
# Create the model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=maxnorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile model
epochs = 25
lrate = 0.01
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 32, 32, 32)        896
#
#  dropout_24 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_12 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 8192)              0
#
#  dense_12 (Dense)            (None, 512)               4194816
#
#  dropout_25 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 4,210,090
# Trainable params: 4,210,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.6601 - accuracy: 0.3984 - val_loss: 1.3558 - val_accuracy: 0.5096
# Epoch 2/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.2911 - accuracy: 0.5383 - val_loss: 1.2005 - val_accuracy: 0.5754
# Epoch 3/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1376 - accuracy: 0.5966 - val_loss: 1.0764 - val_accuracy: 0.6174
# Epoch 4/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0273 - accuracy: 0.6329 - val_loss: 1.0339 - val_accuracy: 0.6378
# Epoch 5/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9332 - accuracy: 0.6673 - val_loss: 0.9951 - val_accuracy: 0.6493
# Epoch 6/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.8599 - accuracy: 0.6952 - val_loss: 0.9526 - val_accuracy: 0.6684
# Epoch 7/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7852 - accuracy: 0.7231 - val_loss: 0.9392 - val_accuracy: 0.6729
# Epoch 8/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7255 - accuracy: 0.7446 - val_loss: 0.9210 - val_accuracy: 0.6822
# Epoch 9/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6700 - accuracy: 0.7628 - val_loss: 0.9290 - val_accuracy: 0.6877
# Epoch 10/25
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.6212 - accuracy: 0.7820 - val_loss: 0.9167 - val_accuracy: 0.6909
# Epoch 11/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5749 - accuracy: 0.7969 - val_loss: 0.9434 - val_accuracy: 0.6906
# Epoch 12/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5341 - accuracy: 0.8110 - val_loss: 0.9345 - val_accuracy: 0.6933
# Epoch 13/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4948 - accuracy: 0.8247 - val_loss: 0.9242 - val_accuracy: 0.6993
# Epoch 14/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4578 - accuracy: 0.8377 - val_loss: 0.9497 - val_accuracy: 0.6947
# Epoch 15/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4327 - accuracy: 0.8461 - val_loss: 0.9714 - val_accuracy: 0.6941
# Epoch 16/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4042 - accuracy: 0.8564 - val_loss: 0.9962 - val_accuracy: 0.6953
# Epoch 17/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3765 - accuracy: 0.8668 - val_loss: 0.9991 - val_accuracy: 0.6984
# Epoch 18/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3571 - accuracy: 0.8757 - val_loss: 1.0076 - val_accuracy: 0.6981
# Epoch 19/25
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3360 - accuracy: 0.8818 - val_loss: 1.0232 - val_accuracy: 0.6991
# Epoch 20/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3175 - accuracy: 0.8886 - val_loss: 1.0334 - val_accuracy: 0.6988
# Epoch 21/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2999 - accuracy: 0.8949 - val_loss: 1.0469 - val_accuracy: 0.6994
# Epoch 22/25
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2886 - accuracy: 0.8986 - val_loss: 1.0412 - val_accuracy: 0.7015
# Epoch 23/25
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.2745 - accuracy: 0.9048 - val_loss: 1.0538 - val_accuracy: 0.6986
# Epoch 24/25
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2623 - accuracy: 0.9081 - val_loss: 1.0786 - val_accuracy: 0.7012
# Epoch 25/25
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.2482 - accuracy: 0.9133 - val_loss: 1.0881 - val_accuracy: 0.6992
# Accuracy: 69.92%

# %% [markdown]
# This is the given code corrected the input shape(32 , 32, 3)

# %%
import numpy
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# Create the model
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu'))
model.add(Dropout(0.2))

model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))

model.add(Dense(1024, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))

model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))

model.add(Dense(num_classes, activation='softmax'))

# Compile model
epochs = 15
lrate = 0.01
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

print(model.summary())

# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=64)

# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_26 (Conv2D)          (None, 32, 32, 32)        896
#
#  dropout_26 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_27 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 16, 16, 64)        18496
#
#  dropout_27 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 8, 8, 128)         73856
#
#  dropout_28 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_15 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 2048)              0
#
#  dropout_29 (Dropout)        (None, 2048)              0
#
#  dense_14 (Dense)            (None, 1024)              2098176
#
#  dropout_30 (Dropout)        (None, 1024)              0
#
#  dense_15 (Dense)            (None, 512)               524800
#
#  dropout_31 (Dropout)        (None, 512)               0
#
#  dense_16 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 2,915,114
# Trainable params: 2,915,114
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/15
# 782/782 [==============================] - 10s 12ms/step - loss: 1.9148 - accuracy: 0.2879 - val_loss: 1.6490 - val_accuracy: 0.4081
# Epoch 2/15
# 782/782 [==============================] - 9s 12ms/step - loss: 1.5140 - accuracy: 0.4460 - val_loss: 1.3714 - val_accuracy: 0.5063
# Epoch 3/15
# 782/782 [==============================] - 9s 12ms/step - loss: 1.3386 - accuracy: 0.5173 - val_loss: 1.2562 - val_accuracy: 0.5520
# Epoch 4/15
# 782/782 [==============================] - 9s 12ms/step - loss: 1.2244 - accuracy: 0.5564 - val_loss: 1.1479 - val_accuracy: 0.5889
# Epoch 5/15
# 782/782 [==============================] - 9s 12ms/step - loss: 1.1355 - accuracy: 0.5925 - val_loss: 1.0868 - val_accuracy: 0.6067
# Epoch 6/15
# 782/782 [==============================] - 9s 11ms/step - loss: 1.0596 - accuracy: 0.6223 - val_loss: 1.0046 - val_accuracy: 0.6419
# Epoch 7/15
# 782/782 [==============================] - 9s 11ms/step - loss: 1.0026 - accuracy: 0.6392 - val_loss: 0.9861 - val_accuracy: 0.6450
# Epoch 8/15
# 782/782 [==============================] - 9s 12ms/step - loss: 0.9542 - accuracy: 0.6602 - val_loss: 0.9377 - val_accuracy: 0.6682
# Epoch 9/15
# 782/782 [==============================] - 9s 12ms/step - loss: 0.9057 - accuracy: 0.6771 - val_loss: 0.8826 - val_accuracy: 0.6871
# Epoch 10/15
# 782/782 [==============================] - 9s 11ms/step - loss: 0.8675 - accuracy: 0.6891 - val_loss: 0.8588 - val_accuracy: 0.6913
# Epoch 11/15
# 782/782 [==============================] - 9s 12ms/step - loss: 0.8328 - accuracy: 0.7061 - val_loss: 0.8257 - val_accuracy: 0.7074
# Epoch 12/15
# 782/782 [==============================] - 9s 12ms/step - loss: 0.8005 - accuracy: 0.7157 - val_loss: 0.8165 - val_accuracy: 0.7077
# Epoch 13/15
# 782/782 [==============================] - 9s 11ms/step - loss: 0.7771 - accuracy: 0.7242 - val_loss: 0.7939 - val_accuracy: 0.7197
# Epoch 14/15
# 782/782 [==============================] - 9s 11ms/step - loss: 0.7491 - accuracy: 0.7351 - val_loss: 0.7754 - val_accuracy: 0.7250
# Epoch 15/15
# 782/782 [==============================] - 9s 12ms/step - loss: 0.7277 - accuracy: 0.7434 - val_loss: 0.7432 - val_accuracy: 0.7352
# Accuracy: 73.52%

# %% [markdown]
# added several convolutional layers as given in ICP after increasing the layers accuracy increased from 69 to 73

# %%
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils

# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# Create the model
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu'))
model.add(Dropout(0.2))

model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))

model.add(Dense(1024, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))

model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))

model.add(Dense(num_classes, activation='softmax'))

# Compile model
epochs = 10
lrate = 0.01
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

print(model.summary())

# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=64)

# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))

# Predict the first 4 images of the test data
y_pred = model.predict(X_test[:4])

# Get the corresponding class labels
class_labels = np.argmax(y_test[:4], axis=1)

# Compare the predicted and true labels
for i in range(4):
    print("Predicted label: ", y_pred[i])
    print("True label: ", class_labels[i])


import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  dropout_6 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  dropout_7 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         73856
#
#  dropout_8 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dropout_9 (Dropout)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 1024)              2098176
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,915,114
# Trainable params: 2,915,114
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# None
# Epoch 1/10
# 782/782 [==============================] - 10s 12ms/step - loss: 1.9368 - accuracy: 0.2875 - val_loss: 1.7519 - val_accuracy: 0.3760
# Epoch 2/10
# 782/782 [==============================] - 9s 11ms/step - loss: 1.5344 - accuracy: 0.4422 - val_loss: 1.4130 - val_accuracy: 0.5009
# Epoch 3/10
# 782/782 [==============================] - 9s 12ms/step - loss: 1.3885 - accuracy: 0.4970 - val_loss: 1.3460 - val_accuracy: 0.5247
# Epoch 4/10
# 782/782 [==============================] - 9s 12ms/step - loss: 1.2894 - accuracy: 0.5354 - val_loss: 1.2587 - val_accuracy: 0.5383
# Epoch 5/10
# 782/782 [==============================] - 9s 12ms/step - loss: 1.2180 - accuracy: 0.5614 - val_loss: 1.1877 - val_accuracy: 0.5779
# Epoch 6/10
# 782/782 [==============================] - 9s 12ms/step - loss: 1.1558 - accuracy: 0.5819 - val_loss: 1.1041 - val_accuracy: 0.6061
# Epoch 7/10
# 782/782 [==============================] - 9s 11ms/step - loss: 1.1044 - accuracy: 0.6040 - val_loss: 1.0981 - val_accuracy: 0.6089
# Epoch 8/10
# 782/782 [==============================] - 9s 12ms/step - loss: 1.0596 - accuracy: 0.6203 - val_loss: 1.0590 - val_accuracy: 0.6226
# Epoch 9/10
# 782/782 [==============================] - 9s 12ms/step - loss: 1.0223 - accuracy: 0.6345 - val_loss: 1.0013 - val_accuracy: 0.6429
# Epoch 10/10
# 782/782 [==============================] - 9s 11ms/step - loss: 0.9875 - accuracy: 0.6472 - val_loss: 0.9771 - val_accuracy: 0.6511
# Accuracy: 65.11%
# 1/1 [==============================] - 0s 108ms/step
# Predicted label:  [0.01048282 0.00837569 0.0281688  0.41528893 0.06529766 0.38887694
#  0.04930611 0.01958562 0.01208292 0.0025345 ]
# True label:  3
# Predicted label:  [3.4449048e-02 4.2511511e-01 1.3699703e-04 2.8452454e-05 2.5036918e-05
#  2.0519240e-06 9.0149315e-06 3.7812060e-06 5.3772879e-01 2.5017513e-03]
# True label:  8
# Predicted label:  [7.1220942e-02 5.0607640e-02 1.0040486e-03 6.1770901e-04 8.0227165e-04
#  2.4991200e-04 1.5745044e-04 1.0384603e-03 8.6687374e-01 7.4278037e-03]
# True label:  8
# Predicted label:  [7.6581973e-01 2.0316670e-02 1.7373005e-02 8.6115283e-04 6.5334397e-03
#  9.8278811e-05 3.0351037e-04 5.0535810e-04 1.8607090e-01 2.1179460e-03]
# True label:  0

# %% [markdown]
# Pridicted the first 4 images of test day and printed the pridicted lable and acctual label and plotted the Loss and Accuracy using history object
