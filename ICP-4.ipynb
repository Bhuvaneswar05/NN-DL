# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data_frame = pd.read_csv("data.csv")

# the basic statistical description about the data
print(data_frame.describe())

# Check if the data has null values
print("Null values:", data_frame.isnull().sum())

# if data has null values then Replace the null values with the mean
data_frame = data_frame.fillna(data.mean())

# Select two columns and aggregate the data using min, max, count, mean
df_calories = data_frame["Calories"]
df_duration = data_frame["Duration"]
print("Calories:", df_calories.agg([min, max, len, "mean"]))
print("Duration:", df_duration.agg([min, max, len, "mean"]))

# Filter the dataframe to select the rows with calories values between 500 and 1000
df1_filtered = data_frame[(data_frame["Calories"] >= 500) & (data_frame["Calories"] <= 1000)]

# print(df1_filtered)

#  Filter the dataframe to select the rows with calories values > 500 and pulse < 100
df2_filtered = data_frame[(data_frame["Calories"] > 500) & (data_frame["Pulse"] < 100)]

# print(df2_filtered)

# Create a new "df_modified" dataframe that contains all columns except "Maxpulse"
df_modified = data_frame.drop("Maxpulse", axis=1)

# print(df_modified)

# Delete the "Maxpulse" column from the main df dataframe
data_frame = data_frame.drop("Maxpulse", axis=1)

# Convert the datatype of Calories column to int datatype
data_frame["Calories"] = data_frame["Calories"].astype(int)

# Create a scatter plot for the two columns (Duration and Calories)
plt.scatter(data_frame["Duration"], data_frame["Calories"])
plt.xlabel("Duration")
plt.ylabel("Calories")
plt.title("Duration vs Calories")
plt.show()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000
# Null values: Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64
# Calories: min       50.30000
# max     1860.40000
# len      169.00000
# mean     375.78297
# Name: Calories, dtype: float64
# Duration: min      15.000000
# max     300.000000
# len     169.000000
# mean     63.846154
# Name: Duration, dtype: float64

# %% [markdown]
# The code reads the data using the Pandas library and performs various operations to clean and analyze the data.
#
# saved the data frame to data_frame value CSV file into a Pandas data frame using the "pd.read_csv" function.
#
# Print a summary of the data using the "describe" method of the data frame.
#
# Checked if the data frame has any null values using the "isnull" method and the "sum" method.
#
# If there are any null values, replace them with the mean value of the column using the "fillna" method.
#
# Selected two columns from the data frame and use the "agg" method to calculate statistics such as min, max, count, and mean for each column.
#
# Filtered the data frame to select rows based on certain conditions. For example, select rows where the "Calories" column is between 500 and 1000.
#
# Created a new data frame that contains a subset of the columns from the original data frame, by dropping certain columns such as the "Maxpulse" column.
#
# Converted the data type of a specific column, for example, converting the "Calories" column to an integer data type.
#
# Finally, created scatter plot using the Matplotlib library to visualize the relationship between two columns, such as "Duration" and "Calories".

# %%
# Simple Linear Regression
# Importing the libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the datasets
data = pd.read_csv("Salary_Data.csv")

X = data.iloc[:, :-1].values
Y = data.iloc[:, 1].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X , Y , test_size=1/3 , random_state=0)

# Fitting Simple Linear Regression to the training set

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_Train, Y_Train)

# Predicting the Test set result
Y_Pred = regressor.predict(X_Test)


# Calculated the mean_squared error
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_Test, Y_Pred)
print("Mean Squared Error:", mse)

# Visualizing train data using scatter plot
plt.scatter(X_Train, Y_Train, color="black")
plt.plot(X_Train, regressor.predict(X_Train), color="red")
plt.title("Salary vs Experience - Training set")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# Visualizing test data using scatter plot
plt.scatter(X_Test, Y_Test, color="black")
plt.plot(X_Train, regressor.predict(X_Train), color="red")
plt.title("Salary vs Experience - Test set")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()
# Out:
# Mean Squared Error: 21026037.329511296

# %% [markdown]
# Here for simple linear regression in python using the scikit-learn library. First imported the necessary libraries (numpy, matplotlib and pandas). Then it imports the "Salary_Data.csv" as a pandas dataframe and saved in data variable, separates the independent variable (X) and dependent variable (Y), splits the dataset into training and testing sets. Next, it fits a linear regression model to the training data using the LinearRegression class. The code then uses the fitted model to predict the salary based on experience for the test data. Finally, it calculates the mean squared error (MSE) between the actual and predicted values for the test data, and plots the results in a scatter plot for both the training and test sets.
