# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD, Adam
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
warnings.filterwarnings("ignore")


(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

y_train = y_train.reshape(-1,)
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)
# Reshape and normalization
# x_train = tf.image.resize(x_train, (64, 64))
# x_test = tf.image.resize(x_test, (64, 64))

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape)

#Define Alexnet Model
AlexNet =  Sequential()
AlexNet.add(Conv2D(filters=16, kernel_size=(3,3), strides=(4,4), input_shape=(32, 32, 3), activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(5,5),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(30,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(20,(3,3),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Flatten())
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(10,activation='softmax'))

AlexNet.compile(optimizer='SGD', loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
AlexNet.summary()


history1 = AlexNet.fit(x_train , y_train , epochs=100, batch_size=128, validation_data=(x_test, y_test),verbose=1)
# Out:
# (50000, 32, 32, 3)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 8, 8, 16)          448
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 16)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 60)          24060
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 60)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 60)          32460
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 30)          16230
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 20)          5420
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 20)         0
#  2D)
#
#  flatten (Flatten)           (None, 20)                0
#
#  dense (Dense)               (None, 200)               4200
#
#  dropout (Dropout)           (None, 200)               0
#
#  dense_1 (Dense)             (None, 200)               40200
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 10)                2010
#
# =================================================================
# Total params: 125,028
# Trainable params: 125,028
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 391/391 [==============================] - 14s 8ms/step - loss: 2.3016 - accuracy: 0.1403 - val_loss: 2.3004 - val_accuracy: 0.1765
# Epoch 2/100
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2991 - accuracy: 0.1667 - val_loss: 2.2969 - val_accuracy: 0.1946
# Epoch 3/100
# 391/391 [==============================] - 3s 6ms/step - loss: 2.2937 - accuracy: 0.1774 - val_loss: 2.2882 - val_accuracy: 0.1872
# Epoch 4/100
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2793 - accuracy: 0.1824 - val_loss: 2.2635 - val_accuracy: 0.1893
# Epoch 5/100
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2325 - accuracy: 0.1826 - val_loss: 2.1802 - val_accuracy: 0.1877
# Epoch 6/100
# 391/391 [==============================] - 3s 7ms/step - loss: 2.1265 - accuracy: 0.1894 - val_loss: 2.1362 - val_accuracy: 0.1894
# Epoch 7/100
# 391/391 [==============================] - 3s 7ms/step - loss: 2.0795 - accuracy: 0.2013 - val_loss: 2.0782 - val_accuracy: 0.2110
# Epoch 8/100
# 391/391 [==============================] - 3s 6ms/step - loss: 2.0560 - accuracy: 0.2112 - val_loss: 2.0102 - val_accuracy: 0.2385
# Epoch 9/100
# 391/391 [==============================] - 3s 7ms/step - loss: 2.0317 - accuracy: 0.2247 - val_loss: 2.0232 - val_accuracy: 0.2296
# Epoch 10/100
# 391/391 [==============================] - 3s 7ms/step - loss: 2.0023 - accuracy: 0.2359 - val_loss: 1.9629 - val_accuracy: 0.2600
# Epoch 11/100
# 391/391 [==============================] - 4s 9ms/step - loss: 1.9730 - accuracy: 0.2480 - val_loss: 1.9583 - val_accuracy: 0.2531
# Epoch 12/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.9361 - accuracy: 0.2588 - val_loss: 1.8964 - val_accuracy: 0.2782
# Epoch 13/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.8996 - accuracy: 0.2694 - val_loss: 1.8336 - val_accuracy: 0.3042
# Epoch 14/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.8664 - accuracy: 0.2794 - val_loss: 1.8139 - val_accuracy: 0.3073
# Epoch 15/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.8261 - accuracy: 0.2919 - val_loss: 1.8274 - val_accuracy: 0.2976
# Epoch 16/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.7967 - accuracy: 0.3007 - val_loss: 1.7545 - val_accuracy: 0.3283
# Epoch 17/100
# 391/391 [==============================] - 3s 6ms/step - loss: 1.7679 - accuracy: 0.3116 - val_loss: 1.7211 - val_accuracy: 0.3324
# Epoch 18/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.7409 - accuracy: 0.3298 - val_loss: 1.6955 - val_accuracy: 0.3488
# Epoch 19/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7164 - accuracy: 0.3356 - val_loss: 1.6810 - val_accuracy: 0.3567
# Epoch 20/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6947 - accuracy: 0.3447 - val_loss: 1.6465 - val_accuracy: 0.3689
# Epoch 21/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6709 - accuracy: 0.3574 - val_loss: 1.6487 - val_accuracy: 0.3675
# Epoch 22/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6529 - accuracy: 0.3625 - val_loss: 1.6677 - val_accuracy: 0.3609
# Epoch 23/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6364 - accuracy: 0.3699 - val_loss: 1.6059 - val_accuracy: 0.3827
# Epoch 24/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6221 - accuracy: 0.3765 - val_loss: 1.6662 - val_accuracy: 0.3656
# Epoch 25/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.6010 - accuracy: 0.3853 - val_loss: 1.6094 - val_accuracy: 0.3885
# Epoch 26/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.5870 - accuracy: 0.3939 - val_loss: 1.6567 - val_accuracy: 0.3785
# Epoch 27/100
# 391/391 [==============================] - 3s 6ms/step - loss: 1.5735 - accuracy: 0.4007 - val_loss: 1.6613 - val_accuracy: 0.3715
# Epoch 28/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.5550 - accuracy: 0.4093 - val_loss: 1.5485 - val_accuracy: 0.4115
# Epoch 29/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.5401 - accuracy: 0.4167 - val_loss: 1.5103 - val_accuracy: 0.4300
# Epoch 30/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.5265 - accuracy: 0.4223 - val_loss: 1.5658 - val_accuracy: 0.4056
# Epoch 31/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.5123 - accuracy: 0.4300 - val_loss: 1.5240 - val_accuracy: 0.4263
# Epoch 32/100
# 391/391 [==============================] - 3s 6ms/step - loss: 1.4942 - accuracy: 0.4374 - val_loss: 1.4798 - val_accuracy: 0.4411
# Epoch 33/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4729 - accuracy: 0.4469 - val_loss: 1.4790 - val_accuracy: 0.4448
# Epoch 34/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4551 - accuracy: 0.4569 - val_loss: 1.4711 - val_accuracy: 0.4500
# Epoch 35/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4335 - accuracy: 0.4678 - val_loss: 1.5461 - val_accuracy: 0.4297
# Epoch 36/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4209 - accuracy: 0.4710 - val_loss: 1.4552 - val_accuracy: 0.4577
# Epoch 37/100
# 391/391 [==============================] - 2s 6ms/step - loss: 1.4025 - accuracy: 0.4808 - val_loss: 1.4487 - val_accuracy: 0.4701
# Epoch 38/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3828 - accuracy: 0.4876 - val_loss: 1.4346 - val_accuracy: 0.4779
# Epoch 39/100
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3745 - accuracy: 0.4899 - val_loss: 1.4191 - val_accuracy: 0.4779
# Epoch 40/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3562 - accuracy: 0.4995 - val_loss: 1.4210 - val_accuracy: 0.4793
# Epoch 41/100
# 391/391 [==============================] - 3s 6ms/step - loss: 1.3421 - accuracy: 0.5047 - val_loss: 1.4275 - val_accuracy: 0.4773
# Epoch 42/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3297 - accuracy: 0.5128 - val_loss: 1.3612 - val_accuracy: 0.5000
# Epoch 43/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3185 - accuracy: 0.5144 - val_loss: 1.4661 - val_accuracy: 0.4789
# Epoch 44/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3066 - accuracy: 0.5189 - val_loss: 1.3483 - val_accuracy: 0.5094
# Epoch 45/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2918 - accuracy: 0.5272 - val_loss: 1.3860 - val_accuracy: 0.4952
# Epoch 46/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2822 - accuracy: 0.5309 - val_loss: 1.3234 - val_accuracy: 0.5193
# Epoch 47/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2677 - accuracy: 0.5369 - val_loss: 1.3226 - val_accuracy: 0.5207
# Epoch 48/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2627 - accuracy: 0.5367 - val_loss: 1.3486 - val_accuracy: 0.5093
# Epoch 49/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2494 - accuracy: 0.5430 - val_loss: 1.3603 - val_accuracy: 0.5062
# Epoch 50/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2374 - accuracy: 0.5480 - val_loss: 1.3499 - val_accuracy: 0.5160
# Epoch 51/100
# 391/391 [==============================] - 3s 9ms/step - loss: 1.2300 - accuracy: 0.5498 - val_loss: 1.3430 - val_accuracy: 0.5131
# Epoch 52/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2204 - accuracy: 0.5541 - val_loss: 1.3295 - val_accuracy: 0.5190
# Epoch 53/100
# 391/391 [==============================] - 3s 6ms/step - loss: 1.2132 - accuracy: 0.5591 - val_loss: 1.3064 - val_accuracy: 0.5285
# Epoch 54/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2069 - accuracy: 0.5603 - val_loss: 1.3602 - val_accuracy: 0.5105
# Epoch 55/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1948 - accuracy: 0.5646 - val_loss: 1.3603 - val_accuracy: 0.5127
# Epoch 56/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1851 - accuracy: 0.5696 - val_loss: 1.2883 - val_accuracy: 0.5402
# Epoch 57/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1829 - accuracy: 0.5696 - val_loss: 1.3386 - val_accuracy: 0.5248
# Epoch 58/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1739 - accuracy: 0.5729 - val_loss: 1.3697 - val_accuracy: 0.5165
# Epoch 59/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1639 - accuracy: 0.5770 - val_loss: 1.3112 - val_accuracy: 0.5323
# Epoch 60/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1625 - accuracy: 0.5762 - val_loss: 1.2966 - val_accuracy: 0.5391
# Epoch 61/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1425 - accuracy: 0.5843 - val_loss: 1.3180 - val_accuracy: 0.5371
# Epoch 62/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1413 - accuracy: 0.5840 - val_loss: 1.3339 - val_accuracy: 0.5291
# Epoch 63/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1337 - accuracy: 0.5886 - val_loss: 1.3171 - val_accuracy: 0.5387
# Epoch 64/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1281 - accuracy: 0.5897 - val_loss: 1.3262 - val_accuracy: 0.5300
# Epoch 65/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1180 - accuracy: 0.5938 - val_loss: 1.3385 - val_accuracy: 0.5292
# Epoch 66/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1090 - accuracy: 0.5983 - val_loss: 1.3718 - val_accuracy: 0.5229
# Epoch 67/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1043 - accuracy: 0.6002 - val_loss: 1.3334 - val_accuracy: 0.5352
# Epoch 68/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0988 - accuracy: 0.6027 - val_loss: 1.3770 - val_accuracy: 0.5217
# Epoch 69/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0923 - accuracy: 0.6039 - val_loss: 1.3096 - val_accuracy: 0.5368
# Epoch 70/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0869 - accuracy: 0.6073 - val_loss: 1.4240 - val_accuracy: 0.5150
# Epoch 71/100
# 391/391 [==============================] - 3s 6ms/step - loss: 1.0785 - accuracy: 0.6108 - val_loss: 1.3089 - val_accuracy: 0.5430
# Epoch 72/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0763 - accuracy: 0.6126 - val_loss: 1.2791 - val_accuracy: 0.5542
# Epoch 73/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0679 - accuracy: 0.6137 - val_loss: 1.3601 - val_accuracy: 0.5361
# Epoch 74/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0609 - accuracy: 0.6187 - val_loss: 1.3415 - val_accuracy: 0.5382
# Epoch 75/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0538 - accuracy: 0.6189 - val_loss: 1.3833 - val_accuracy: 0.5282
# Epoch 76/100
# 391/391 [==============================] - 3s 6ms/step - loss: 1.0483 - accuracy: 0.6201 - val_loss: 1.3048 - val_accuracy: 0.5448
# Epoch 77/100
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0464 - accuracy: 0.6225 - val_loss: 1.2898 - val_accuracy: 0.5500
# Epoch 78/100
# 391/391 [==============================] - 5s 12ms/step - loss: 1.0346 - accuracy: 0.6274 - val_loss: 1.3909 - val_accuracy: 0.5301
# Epoch 79/100
# 391/391 [==============================] - 5s 12ms/step - loss: 1.0300 - accuracy: 0.6300 - val_loss: 1.2864 - val_accuracy: 0.5565
# Epoch 80/100
# 391/391 [==============================] - 6s 14ms/step - loss: 1.0244 - accuracy: 0.6315 - val_loss: 1.2888 - val_accuracy: 0.5577
# Epoch 81/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0153 - accuracy: 0.6341 - val_loss: 1.4114 - val_accuracy: 0.5268
# Epoch 82/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0122 - accuracy: 0.6356 - val_loss: 1.3393 - val_accuracy: 0.5469
# Epoch 83/100
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0139 - accuracy: 0.6360 - val_loss: 1.3388 - val_accuracy: 0.5468
# Epoch 84/100
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9977 - accuracy: 0.6400 - val_loss: 1.3201 - val_accuracy: 0.5470
# Epoch 85/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9943 - accuracy: 0.6424 - val_loss: 1.3149 - val_accuracy: 0.5491
# Epoch 86/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9876 - accuracy: 0.6446 - val_loss: 1.3921 - val_accuracy: 0.5261
# Epoch 87/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9878 - accuracy: 0.6437 - val_loss: 1.3259 - val_accuracy: 0.5401
# Epoch 88/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.9785 - accuracy: 0.6476 - val_loss: 1.3194 - val_accuracy: 0.5564
# Epoch 89/100
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9785 - accuracy: 0.6468 - val_loss: 1.3398 - val_accuracy: 0.5432
# Epoch 90/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9696 - accuracy: 0.6532 - val_loss: 1.3446 - val_accuracy: 0.5397
# Epoch 91/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9616 - accuracy: 0.6565 - val_loss: 1.3379 - val_accuracy: 0.5461
# Epoch 92/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9564 - accuracy: 0.6559 - val_loss: 1.3550 - val_accuracy: 0.5478
# Epoch 93/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9454 - accuracy: 0.6602 - val_loss: 1.3991 - val_accuracy: 0.5322
# Epoch 94/100
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9485 - accuracy: 0.6583 - val_loss: 1.3460 - val_accuracy: 0.5502
# Epoch 95/100
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9350 - accuracy: 0.6648 - val_loss: 1.3695 - val_accuracy: 0.5412
# Epoch 96/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9359 - accuracy: 0.6645 - val_loss: 1.3934 - val_accuracy: 0.5356
# Epoch 97/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9290 - accuracy: 0.6663 - val_loss: 1.3365 - val_accuracy: 0.5538
# Epoch 98/100
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9330 - accuracy: 0.6643 - val_loss: 1.4846 - val_accuracy: 0.5108
# Epoch 99/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.9182 - accuracy: 0.6704 - val_loss: 1.3487 - val_accuracy: 0.5524
# Epoch 100/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.9154 - accuracy: 0.6716 - val_loss: 1.3410 - val_accuracy: 0.5470

# %%
# summarize history for accuracy
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title("Accuracy by AlexNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Loss by AlexNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()
y_predictions1 = AlexNet.predict(x_test)
y_predictions1.reshape(-1,)
y_predictions1= np.argmax(y_predictions1, axis=1)

confusion_matrix(y_test, y_predictions1)
# confusion matrix and accuracy
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix of AlexNet Model', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions1))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()

# print("Test accuracy by AlexNet:", accuracy_score(y_test, y_predictions))
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions1[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# **AlexNet with cifer10 dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD, Adam
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
warnings.filterwarnings("ignore")


(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

y_train = y_train.reshape(-1,)
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)
# Reshape and normalization
# x_train = tf.image.resize(x_train, (64, 64))
# x_test = tf.image.resize(x_test, (64, 64))

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape)

#Define Alexnet Model
AlexNet =  Sequential()
AlexNet.add(Conv2D(filters=16, kernel_size=(3,3), strides=(4,4), input_shape=(32, 32, 3), activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(5,5),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(30,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(20,(3,3),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Flatten())
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(400, activation='relu'))
AlexNet.add(Dropout(0.3))
AlexNet.add(Dense(10,activation='softmax'))

learning_rate = 0.001
optimizer = SGD(learning_rate=learning_rate)

AlexNet.compile(optimizer=optimizer, loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
AlexNet.summary()


history1 = AlexNet.fit(x_train , y_train , epochs=50, batch_size=128, validation_data=(x_test, y_test),verbose=1)

# summarize history for accuracy
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title("Accuracy by AlexNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Loss by AlexNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()
y_predictions1 = AlexNet.predict(x_test)
y_predictions1.reshape(-1,)
y_predictions1= np.argmax(y_predictions1, axis=1)

confusion_matrix(y_test, y_predictions1)
# confusion matrix and accuracy
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix of AlexNet Model', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions1))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()

# print("Test accuracy by AlexNet:", accuracy_score(y_test, y_predictions))
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions1[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
# Out:
# (50000, 32, 32, 3)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 8, 8, 16)          448
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 60)          24060
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 60)         0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 2, 2, 60)          32460
#
#  conv2d_13 (Conv2D)          (None, 2, 2, 30)          16230
#
#  conv2d_14 (Conv2D)          (None, 2, 2, 20)          5420
#
#  max_pooling2d_8 (MaxPooling  (None, 1, 1, 20)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 20)                0
#
#  dense_10 (Dense)            (None, 200)               4200
#
#  dropout_4 (Dropout)         (None, 200)               0
#
#  dense_11 (Dense)            (None, 400)               80400
#
#  dropout_5 (Dropout)         (None, 400)               0
#
#  dense_12 (Dense)            (None, 10)                4010
#
# =================================================================
# Total params: 167,228
# Trainable params: 167,228
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 391/391 [==============================] - 4s 8ms/step - loss: 2.3025 - accuracy: 0.1009 - val_loss: 2.3023 - val_accuracy: 0.1008
# Epoch 2/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3023 - accuracy: 0.1078 - val_loss: 2.3022 - val_accuracy: 0.1028
# Epoch 3/50
# 391/391 [==============================] - 3s 6ms/step - loss: 2.3022 - accuracy: 0.1132 - val_loss: 2.3021 - val_accuracy: 0.1094
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3021 - accuracy: 0.1168 - val_loss: 2.3020 - val_accuracy: 0.1259
# Epoch 5/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3020 - accuracy: 0.1196 - val_loss: 2.3019 - val_accuracy: 0.1408
# Epoch 6/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3020 - accuracy: 0.1256 - val_loss: 2.3018 - val_accuracy: 0.1495
# Epoch 7/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3019 - accuracy: 0.1270 - val_loss: 2.3018 - val_accuracy: 0.1673
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3018 - accuracy: 0.1345 - val_loss: 2.3017 - val_accuracy: 0.1755
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3017 - accuracy: 0.1352 - val_loss: 2.3016 - val_accuracy: 0.1865
# Epoch 10/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3016 - accuracy: 0.1419 - val_loss: 2.3015 - val_accuracy: 0.1862
# Epoch 11/50
# 391/391 [==============================] - 3s 6ms/step - loss: 2.3015 - accuracy: 0.1430 - val_loss: 2.3014 - val_accuracy: 0.1910
# Epoch 12/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3015 - accuracy: 0.1463 - val_loss: 2.3013 - val_accuracy: 0.1917
# Epoch 13/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3014 - accuracy: 0.1490 - val_loss: 2.3013 - val_accuracy: 0.1950
# Epoch 14/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3013 - accuracy: 0.1449 - val_loss: 2.3012 - val_accuracy: 0.2022
# Epoch 15/50
# 391/391 [==============================] - 3s 6ms/step - loss: 2.3012 - accuracy: 0.1519 - val_loss: 2.3011 - val_accuracy: 0.2013
# Epoch 16/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3011 - accuracy: 0.1533 - val_loss: 2.3010 - val_accuracy: 0.2018
# Epoch 17/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3010 - accuracy: 0.1532 - val_loss: 2.3009 - val_accuracy: 0.2039
# Epoch 18/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3009 - accuracy: 0.1581 - val_loss: 2.3007 - val_accuracy: 0.2067
# Epoch 19/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3007 - accuracy: 0.1596 - val_loss: 2.3006 - val_accuracy: 0.2156
# Epoch 20/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3006 - accuracy: 0.1616 - val_loss: 2.3005 - val_accuracy: 0.2202
# Epoch 21/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.3005 - accuracy: 0.1640 - val_loss: 2.3003 - val_accuracy: 0.2250
# Epoch 22/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3004 - accuracy: 0.1634 - val_loss: 2.3002 - val_accuracy: 0.2239
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3003 - accuracy: 0.1634 - val_loss: 2.3001 - val_accuracy: 0.2208
# Epoch 24/50
# 391/391 [==============================] - 3s 6ms/step - loss: 2.3002 - accuracy: 0.1638 - val_loss: 2.2999 - val_accuracy: 0.2163
# Epoch 25/50
# 391/391 [==============================] - 3s 6ms/step - loss: 2.3000 - accuracy: 0.1658 - val_loss: 2.2998 - val_accuracy: 0.2174
# Epoch 26/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2998 - accuracy: 0.1658 - val_loss: 2.2996 - val_accuracy: 0.2182
# Epoch 27/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2997 - accuracy: 0.1672 - val_loss: 2.2994 - val_accuracy: 0.2143
# Epoch 28/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2995 - accuracy: 0.1692 - val_loss: 2.2992 - val_accuracy: 0.2106
# Epoch 29/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.2993 - accuracy: 0.1706 - val_loss: 2.2990 - val_accuracy: 0.2060
# Epoch 30/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2991 - accuracy: 0.1706 - val_loss: 2.2988 - val_accuracy: 0.2012
# Epoch 31/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2989 - accuracy: 0.1699 - val_loss: 2.2986 - val_accuracy: 0.1947
# Epoch 32/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2987 - accuracy: 0.1687 - val_loss: 2.2983 - val_accuracy: 0.1951
# Epoch 33/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2985 - accuracy: 0.1694 - val_loss: 2.2981 - val_accuracy: 0.1883
# Epoch 34/50
# 391/391 [==============================] - 3s 6ms/step - loss: 2.2982 - accuracy: 0.1722 - val_loss: 2.2978 - val_accuracy: 0.1867
# Epoch 35/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2979 - accuracy: 0.1688 - val_loss: 2.2975 - val_accuracy: 0.1848
# Epoch 36/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2976 - accuracy: 0.1715 - val_loss: 2.2972 - val_accuracy: 0.1853
# Epoch 37/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2973 - accuracy: 0.1744 - val_loss: 2.2969 - val_accuracy: 0.1866
# Epoch 38/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2970 - accuracy: 0.1708 - val_loss: 2.2965 - val_accuracy: 0.1899
# Epoch 39/50
# 391/391 [==============================] - 3s 6ms/step - loss: 2.2967 - accuracy: 0.1707 - val_loss: 2.2961 - val_accuracy: 0.1921
# Epoch 40/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2962 - accuracy: 0.1747 - val_loss: 2.2957 - val_accuracy: 0.1923
# Epoch 41/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2959 - accuracy: 0.1755 - val_loss: 2.2953 - val_accuracy: 0.1918
# Epoch 42/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2954 - accuracy: 0.1729 - val_loss: 2.2949 - val_accuracy: 0.1937
# Epoch 43/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2950 - accuracy: 0.1725 - val_loss: 2.2943 - val_accuracy: 0.1944
# Epoch 44/50
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2944 - accuracy: 0.1777 - val_loss: 2.2937 - val_accuracy: 0.1916
# Epoch 45/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2939 - accuracy: 0.1760 - val_loss: 2.2931 - val_accuracy: 0.1899
# Epoch 46/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2933 - accuracy: 0.1741 - val_loss: 2.2925 - val_accuracy: 0.1895
# Epoch 47/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2927 - accuracy: 0.1749 - val_loss: 2.2917 - val_accuracy: 0.1874
# Epoch 48/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2920 - accuracy: 0.1768 - val_loss: 2.2910 - val_accuracy: 0.1858
# Epoch 49/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2912 - accuracy: 0.1755 - val_loss: 2.2901 - val_accuracy: 0.1818
# Epoch 50/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2904 - accuracy: 0.1763 - val_loss: 2.2892 - val_accuracy: 0.1785
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# **AlexNet with minist data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD, Adam
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
warnings.filterwarnings("ignore")


(x_train, y_train), (x_test, y_test)  = keras.datasets.mnist.load_data()

classes = [str(i) for i in range(10)]

y_train = y_train.reshape(-1,)
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)
# Reshape and normalization
# x_train = tf.image.resize(x_train, (32, 32))
# x_test = tf.image.resize(x_test, (32, 32))

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape)

#Define Alexnet Model
AlexNet =  Sequential()
AlexNet.add(Conv2D(filters=16, kernel_size=(3,3), strides=(4,4), input_shape=[28, 28, 1], activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(5,5),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(30,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(20,(3,3),padding='same',activation='relu'))
# AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Flatten())
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(400, activation='relu'))
AlexNet.add(Dropout(0.3))
AlexNet.add(Dense(10,activation='softmax'))

learning_rate = 0.001
optimizer = SGD(learning_rate=learning_rate)

AlexNet.compile(optimizer=optimizer, loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
AlexNet.summary()


history1 = AlexNet.fit(x_train , y_train , epochs=100, batch_size=256, validation_data=(x_test, y_test),verbose=1)

# summarize history for accuracy
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title("Accuracy by AlexNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Loss by AlexNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()
y_predictions1 = AlexNet.predict(x_test)
y_predictions1.reshape(-1,)
y_predictions1= np.argmax(y_predictions1, axis=1)

confusion_matrix(y_test, y_predictions1)
# confusion matrix and accuracy
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix of AlexNet Model', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions1))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()

# print("Test accuracy by AlexNet:", accuracy_score(y_test, y_predictions))
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions1[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
# Out:
# (60000, 28, 28)
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_86 (Conv2D)          (None, 7, 7, 16)          160
#
#  max_pooling2d_47 (MaxPoolin  (None, 3, 3, 16)         0
#  g2D)
#
#  conv2d_87 (Conv2D)          (None, 3, 3, 60)          24060
#
#  max_pooling2d_48 (MaxPoolin  (None, 1, 1, 60)         0
#  g2D)
#
#  conv2d_88 (Conv2D)          (None, 1, 1, 60)          32460
#
#  conv2d_89 (Conv2D)          (None, 1, 1, 30)          16230
#
#  conv2d_90 (Conv2D)          (None, 1, 1, 20)          5420
#
#  flatten_14 (Flatten)        (None, 20)                0
#
#  dense_43 (Dense)            (None, 200)               4200
#
#  dropout_24 (Dropout)        (None, 200)               0
#
#  dense_44 (Dense)            (None, 400)               80400
#
#  dropout_25 (Dropout)        (None, 400)               0
#
#  dense_45 (Dense)            (None, 10)                4010
#
# =================================================================
# Total params: 166,940
# Trainable params: 166,940
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 235/235 [==============================] - 3s 7ms/step - loss: 2.3025 - accuracy: 0.1133 - val_loss: 2.3024 - val_accuracy: 0.1135
# Epoch 2/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3023 - accuracy: 0.1124 - val_loss: 2.3022 - val_accuracy: 0.1135
# Epoch 3/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3022 - accuracy: 0.1124 - val_loss: 2.3021 - val_accuracy: 0.1135
# Epoch 4/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3020 - accuracy: 0.1124 - val_loss: 2.3019 - val_accuracy: 0.1135
# Epoch 5/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3019 - accuracy: 0.1124 - val_loss: 2.3018 - val_accuracy: 0.1135
# Epoch 6/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3018 - accuracy: 0.1124 - val_loss: 2.3017 - val_accuracy: 0.1135
# Epoch 7/100
# 235/235 [==============================] - 3s 11ms/step - loss: 2.3017 - accuracy: 0.1124 - val_loss: 2.3017 - val_accuracy: 0.1135
# Epoch 8/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3017 - accuracy: 0.1124 - val_loss: 2.3016 - val_accuracy: 0.1135
# Epoch 9/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3016 - accuracy: 0.1124 - val_loss: 2.3015 - val_accuracy: 0.1135
# Epoch 10/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3015 - accuracy: 0.1124 - val_loss: 2.3014 - val_accuracy: 0.1135
# Epoch 11/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3015 - accuracy: 0.1124 - val_loss: 2.3014 - val_accuracy: 0.1135
# Epoch 12/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3015 - accuracy: 0.1124 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 13/100
# 235/235 [==============================] - 3s 11ms/step - loss: 2.3014 - accuracy: 0.1124 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 14/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3014 - accuracy: 0.1124 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 15/100
# 235/235 [==============================] - 2s 10ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 16/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 17/100
# 235/235 [==============================] - 3s 11ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 18/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 19/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 20/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 21/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3011 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 22/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3011 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 23/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3011 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 24/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3011 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 25/100
# 235/235 [==============================] - 2s 10ms/step - loss: 2.3011 - accuracy: 0.1124 - val_loss: 2.3009 - val_accuracy: 0.1135
# Epoch 26/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3011 - accuracy: 0.1124 - val_loss: 2.3009 - val_accuracy: 0.1135
# Epoch 27/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3011 - accuracy: 0.1124 - val_loss: 2.3009 - val_accuracy: 0.1135
# Epoch 28/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3009 - val_accuracy: 0.1135
# Epoch 29/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3009 - val_accuracy: 0.1135
# Epoch 30/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3009 - val_accuracy: 0.1135
# Epoch 31/100
# 235/235 [==============================] - 4s 15ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3009 - val_accuracy: 0.1135
# Epoch 32/100
# 235/235 [==============================] - 2s 10ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3009 - val_accuracy: 0.1135
# Epoch 33/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 34/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 35/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 36/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 37/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 38/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 39/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 40/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3010 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 41/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 42/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 43/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 44/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 45/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 46/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 47/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 48/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 49/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3008 - val_accuracy: 0.1135
# Epoch 50/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 51/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 52/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 53/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 54/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 55/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 56/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 57/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 58/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 59/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 60/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 61/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 62/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 63/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 64/100
# 235/235 [==============================] - 2s 10ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 65/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 66/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 67/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 68/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 69/100
# 235/235 [==============================] - 2s 10ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 70/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 71/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 72/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 73/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3009 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 74/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3007 - val_accuracy: 0.1135
# Epoch 75/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 76/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 77/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 78/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 79/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 80/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 81/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 82/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 83/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 84/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 85/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 86/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 87/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 88/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 89/100
# 235/235 [==============================] - 2s 9ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 90/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 91/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 92/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 93/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 94/100
# 235/235 [==============================] - 2s 8ms/step - loss: 2.3008 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 95/100
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3006 - val_accuracy: 0.1135
# Epoch 96/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3005 - val_accuracy: 0.1135
# Epoch 97/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3005 - val_accuracy: 0.1135
# Epoch 98/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3005 - val_accuracy: 0.1135
# Epoch 99/100
# 235/235 [==============================] - 2s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3005 - val_accuracy: 0.1135
# Epoch 100/100
# 235/235 [==============================] - 1s 6ms/step - loss: 2.3007 - accuracy: 0.1124 - val_loss: 2.3005 - val_accuracy: 0.1135
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Aplied batch_size change and learning rate change but is accuracy is low

# %% [markdown]
# **VGG16 with cifer-10**

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation,Dense,Dropout,Conv2D,Flatten,MaxPooling2D
from keras.datasets import cifar10
from keras import optimizers
from matplotlib import pyplot as plt

# generate cifar10 data
(x_train,y_train),(x_test,y_test) = cifar10.load_data()

# config parameters
num_classes = 10
input_shape = x_train.shape[1:4]
optimizer = optimizers.Adam(lr=0.0003)

# convert label to one-hot
one_hot_y_train = keras.utils.to_categorical(y_train,num_classes=num_classes)
one_hot_y_test = keras.utils.to_categorical(y_test,num_classes=num_classes)

# check data
plt.imshow(x_train[1])
print(x_train[1].shape)

# build model(similar to VGG16, only change the input and output shape)
model = Sequential()
model.add(Conv2D(64,(3,3),activation='relu',input_shape=input_shape,padding='same'))
model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Flatten())
model.add(Dense(4096,activation='relu'))
model.add(Dense(4096,activation='relu'))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# config optimizer,loss,metrics
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])

# check model
model.summary()

# train
model.fit(x=x_train,y=one_hot_y_train,batch_size=128,epochs=10)

# evaluate
print(model.metrics_names)
model.evaluate(x=x_test,y=one_hot_y_test,batch_size=512)

# predict
plt.imshow(x_test[1000])

result = model.predict(x_test[1000:1001]).tolist()
predict = 0
expect = y_test[1000][0]
for i,_ in enumerate(result[0]):
    if result[0][i] > result[0][predict]:
        predict = i
print("predict class:",predict)
print("expected class:",expect)

# save model
model.save("keras-VGG16-cifar10.h5")
# Out:
# (32, 32, 3)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 32, 32, 64)        1792
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 128)       73856
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 256)         295168
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 256)         590080
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 256)         590080
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 256)        0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  conv2d_23 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  max_pooling2d_12 (MaxPoolin  (None, 2, 2, 512)        0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  conv2d_26 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  conv2d_27 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  max_pooling2d_13 (MaxPoolin  (None, 1, 1, 512)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 512)               0
#
#  dense_13 (Dense)            (None, 4096)              2101248
#
#  dense_14 (Dense)            (None, 4096)              16781312
#
#  dense_15 (Dense)            (None, 10)                40970
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 33,638,218
# Trainable params: 33,638,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 27s 63ms/step - loss: 2.1032 - accuracy: 0.1698
# Epoch 2/10
# 391/391 [==============================] - 24s 62ms/step - loss: 1.5831 - accuracy: 0.3813
# Epoch 3/10
# 391/391 [==============================] - 24s 61ms/step - loss: 1.2329 - accuracy: 0.5502
# Epoch 4/10
# 391/391 [==============================] - 23s 60ms/step - loss: 0.9568 - accuracy: 0.6599
# Epoch 5/10
# 391/391 [==============================] - 24s 60ms/step - loss: 0.7736 - accuracy: 0.7289
# Epoch 6/10
# 391/391 [==============================] - 24s 61ms/step - loss: 0.6191 - accuracy: 0.7855
# Epoch 7/10
# 391/391 [==============================] - 24s 61ms/step - loss: 0.5052 - accuracy: 0.8261
# Epoch 8/10
# 391/391 [==============================] - 24s 60ms/step - loss: 0.3882 - accuracy: 0.8680
# Epoch 9/10
# 391/391 [==============================] - 24s 61ms/step - loss: 0.3133 - accuracy: 0.8947
# Epoch 10/10
# 391/391 [==============================] - 24s 61ms/step - loss: 0.2394 - accuracy: 0.9193
# ['loss', 'accuracy']
# 20/20 [==============================] - 5s 124ms/step - loss: 0.8792 - accuracy: 0.7594
# 1/1 [==============================] - 0s 374ms/step
# predict class: 5
# expected class: 5
