# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

y_train = y_train.reshape(-1,)

# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train.shape

from tensorflow.keras import layers, models
lenet = keras.models.Sequential([
    keras.layers.Conv2D(6, kernel_size=5, strides=1,  activation='relu', input_shape=(32,32,3), padding='same'), #C1
    keras.layers.AveragePooling2D(), #S1
    keras.layers.Conv2D(16, kernel_size=5, strides=1, activation='relu', padding='valid'), #C2
    keras.layers.AveragePooling2D(), #S2
    keras.layers.Conv2D(120, kernel_size=5, strides=1, activation='relu', padding='valid'), #C3
    keras.layers.Flatten(), #Flatten    
    keras.layers.Dense(84, activation='relu'), #F1
    keras.layers.Dense(10, activation='softmax') #Output layer
])


lenet.summary()

lenet.compile(optimizer='adam', loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

hist = lenet.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test),verbose=1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

y_train = y_train.reshape(-1,)

# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train.shape

from tensorflow.keras import layers, models
lenet = keras.models.Sequential([
    keras.layers.Conv2D(6, kernel_size=5, strides=1,  activation='relu', input_shape=(32,32,3), padding='same'), #C1
    keras.layers.AveragePooling2D(), #S1
    keras.layers.Conv2D(16, kernel_size=5, strides=1, activation='relu', padding='valid'), #C2
    keras.layers.AveragePooling2D(), #S2
    keras.layers.Conv2D(120, kernel_size=5, strides=1, activation='relu', padding='valid'), #C3
    keras.layers.Flatten(), #Flatten    
    keras.layers.Dense(84, activation='relu'), #F1
    keras.layers.Dense(10, activation='softmax') #Output layer
])

lenet.summary()

learning_rate = 0.001
optimizer = Adam(lr=learning_rate)
batch_size = 128
epochs = 75

lenet.compile(optimizer=optimizer, loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

hist = lenet.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test), verbose=1)

# Plot training and validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 32, 32, 6)         456
#
#  average_pooling2d_2 (Averag  (None, 16, 16, 6)        0
#  ePooling2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 16)        2416
#
#  average_pooling2d_3 (Averag  (None, 6, 6, 16)         0
#  ePooling2D)
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 120)         48120
#
#  flatten_1 (Flatten)         (None, 480)               0
#
#  dense_2 (Dense)             (None, 84)                40404
#
#  dense_3 (Dense)             (None, 10)                850
#
# ...
# Total params: 92,246
# Trainable params: 92,246
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/75
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

y_train = y_train.reshape(-1,)

# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train.shape

from tensorflow.keras import layers, models
lenet = models.Sequential([
    layers.Conv2D(6, kernel_size=5, strides=1,  activation='relu', input_shape=(32,32,3), padding='same'), #C1
    layers.AveragePooling2D(), #S1
    layers.Dropout(0.2), # Dropout regularization
    layers.Conv2D(16, kernel_size=5, strides=1, activation='relu', padding='valid'), #C2
    layers.AveragePooling2D(), #S2
    layers.Dropout(0.2), # Dropout regularization
    layers.Conv2D(120, kernel_size=5, strides=1, activation='relu', padding='valid'), #C3
    layers.Flatten(), #Flatten    
    layers.Dense(84, activation='relu'), #F1
    layers.Dropout(0.2), # Dropout regularization
    layers.Dense(10, activation='softmax') #Output layer
])

lenet.summary()

learning_rate = 0.001
optimizer = Adam(lr=learning_rate)
batch_size = 128
epochs = 75

lenet.compile(optimizer=optimizer, loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

hist = lenet.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test), verbose=1)

# Plot training and validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_9 (Conv2D)           (None, 32, 32, 6)         456
#
#  average_pooling2d_6 (Averag  (None, 16, 16, 6)        0
#  ePooling2D)
#
#  dropout (Dropout)           (None, 16, 16, 6)         0
#
#  conv2d_10 (Conv2D)          (None, 12, 12, 16)        2416
#
#  average_pooling2d_7 (Averag  (None, 6, 6, 16)         0
#  ePooling2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 16)          0
#
#  conv2d_11 (Conv2D)          (None, 2, 2, 120)         48120
#
#  flatten_3 (Flatten)         (None, 480)               0
#
#  dense_6 (Dense)             (None, 84)                40404
#
#  dropout_2 (Dropout)         (None, 84)                0
#
#  dense_7 (Dense)             (None, 10)                850
#
# ...
# Total params: 92,246
# Trainable params: 92,246
# Non-trainable params: 0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

y_train = y_train.reshape(-1,)

# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train.shape

from tensorflow.keras import layers, models
lenet = models.Sequential([
    layers.Conv2D(6, kernel_size=5, strides=1,  activation='relu', input_shape=(32,32,3), padding='same'), #C1
    layers.AveragePooling2D(), #S1
    layers.Dropout(0.2), # Dropout regularization
    layers.Conv2D(16, kernel_size=5, strides=1, activation='relu', padding='valid'), #C2
    layers.AveragePooling2D(), #S2
    layers.Dropout(0.2), # Dropout regularization
    layers.Conv2D(120, kernel_size=5, strides=1, activation='relu', padding='valid'), #C3
    layers.Flatten(), #Flatten    
    layers.Dense(84, activation='relu'), #F1
    layers.Dropout(0.2), # Dropout regularization
    layers.Dense(10, activation='softmax') #Output layer
])

lenet.summary()

learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)
batch_size = 128
epochs = 50

lenet.compile(optimizer="adam", loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

hist = lenet.fit(x_train, y_train,  epochs=epochs, validation_data=(x_test, y_test), verbose=1)

# Plot training and validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 32, 32, 6)         456
#
#  average_pooling2d_9 (Averag  (None, 16, 16, 6)        0
#  ePooling2D)
#
#  dropout_12 (Dropout)        (None, 16, 16, 6)         0
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 16)        2416
#
#  average_pooling2d_10 (Avera  (None, 6, 6, 16)         0
#  gePooling2D)
#
#  dropout_13 (Dropout)        (None, 6, 6, 16)          0
#
#  conv2d_14 (Conv2D)          (None, 2, 2, 120)         48120
#
#  flatten_3 (Flatten)         (None, 480)               0
#
#  dense_6 (Dense)             (None, 84)                40404
#
#  dropout_14 (Dropout)        (None, 84)                0
#
#  dense_7 (Dense)             (None, 10)                850
#
# ...
# Total params: 92,246
# Trainable params: 92,246
# Non-trainable params: 0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

y_train = y_train.reshape(-1,)

# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train.shape

from keras import layers, models

lenet = models.Sequential([
    layers.Conv2D(6, kernel_size=5, strides=1,  activation='relu', input_shape=(32,32,3), padding='same'), #C1
    layers.AveragePooling2D(), #S1
    layers.Dropout(0.2), # Dropout regularization
    layers.Conv2D(16, kernel_size=5, strides=1, activation='relu', padding='valid'), #C2
    layers.AveragePooling2D(), #S2
    layers.Dropout(0.2), # Dropout regularization
    layers.Conv2D(120, kernel_size=5, strides=1, activation='relu', padding='valid'), #C3
    layers.Flatten(), #Flatten  
    layers.Dense(512, activation='relu'), #F1 - increased to 512 units
    layers.Dropout(0.5), # Dropout regularization - increased to 0.5
    layers.Dense(256, activation='relu'), #F2 - added new layer with 256 units
    layers.Dropout(0.3), # Dropout regularization - added new layer with 0.3 dropout rate
    layers.Dense(10, activation='softmax') #Output layer
])

lenet.summary()

learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)
batch_size = 128
epochs = 50

lenet.compile(optimizer, loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

hist = lenet.fit(x_train, y_train,batch_size = batch_size,  epochs=epochs, validation_data=(x_test, y_test), verbose=1)

# Plot training and validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 32, 32, 6)         456
#
#  average_pooling2d_8 (Averag  (None, 16, 16, 6)        0
#  ePooling2D)
#
#  dropout_16 (Dropout)        (None, 16, 16, 6)         0
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 16)        2416
#
#  average_pooling2d_9 (Averag  (None, 6, 6, 16)         0
#  ePooling2D)
#
#  dropout_17 (Dropout)        (None, 6, 6, 16)          0
#
#  conv2d_14 (Conv2D)          (None, 2, 2, 120)         48120
#
#  flatten_4 (Flatten)         (None, 480)               0
#
#  dense_12 (Dense)            (None, 512)               246272
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 256)               131328
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_14 (Dense)            (None, 10)                2570
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

y_train = y_train.reshape(-1,)

# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train.shape

from keras import layers, models

lenet = models.Sequential([
    layers.Conv2D(6, kernel_size=5, strides=1,  activation='relu', input_shape=(32,32,3), padding='same'), #C1
    layers.AveragePooling2D(), #S1
    layers.Dropout(0.2), # Dropout regularization
    layers.Conv2D(16, kernel_size=5, strides=1, activation='relu', padding='valid'), #C2
    layers.AveragePooling2D(), #S2
    layers.Dropout(0.2), # Dropout regularization
    layers.Conv2D(120, kernel_size=5, strides=1, activation='relu', padding='valid'), #C3
    layers.Flatten(), #Flatten  
    layers.Dense(512, activation='relu'), #F1 - increased to 512 units
    layers.Dropout(0.5), # Dropout regularization - increased to 0.5
    layers.Dense(256, activation='relu'), #F2 - added new layer with 256 units
    layers.Dropout(0.3), # Dropout regularization - added new layer with 0.3 dropout rate
    layers.Dense(10, activation='softmax') #Output layer
])

lenet.summary()

learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)
batch_size = 256
epochs = 50

lenet.compile(optimizer, loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])

hist = lenet.fit(x_train, y_train,batch_size = batch_size,  epochs=epochs, validation_data=(x_test, y_test), verbose=1)

# Plot training and validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training and validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_15 (Conv2D)          (None, 32, 32, 6)         456
#
#  average_pooling2d_10 (Avera  (None, 16, 16, 6)        0
#  gePooling2D)
#
#  dropout_20 (Dropout)        (None, 16, 16, 6)         0
#
#  conv2d_16 (Conv2D)          (None, 12, 12, 16)        2416
#
#  average_pooling2d_11 (Avera  (None, 6, 6, 16)         0
#  gePooling2D)
#
#  dropout_21 (Dropout)        (None, 6, 6, 16)          0
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 120)         48120
#
#  flatten_5 (Flatten)         (None, 480)               0
#
#  dense_15 (Dense)            (None, 512)               246272
#
#  dropout_22 (Dropout)        (None, 512)               0
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dropout_23 (Dropout)        (None, 256)               0
#
# ...

# %% [markdown]
# **LeNet on CIFAR-10 Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")
(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
y_train = y_train.reshape(-1,)
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)
# Reshape and normalization
x_train = tf.image.resize(x_train, (64, 64))
x_test = tf.image.resize(x_test, (64, 64))
x_train = x_train / 255.0
x_test = x_test / 255.0

lenet = keras.models.Sequential([
    keras.layers.Conv2D(32, kernel_size=3, strides=1,  activation='relu', input_shape=(64,64,3), padding='same'), #C1
    keras.layers.Conv2D(32, kernel_size=3, strides=1,  activation='relu', padding='same'), #C2
    keras.layers.MaxPooling2D(pool_size=(2,2)), #S1
    keras.layers.Dropout(0.30),
    keras.layers.Conv2D(64, kernel_size=3, strides=1, activation='relu', padding='same'), #C3
    keras.layers.Conv2D(64, kernel_size=3, strides=1, activation='relu', padding='same'), #C4
    keras.layers.MaxPooling2D(pool_size=(2,2)), #S2
    keras.layers.Dropout(0.30),
    keras.layers.Conv2D(128, kernel_size=3, strides=1, activation='relu', padding='same'), #C5
    keras.layers.Conv2D(128, kernel_size=3, strides=1, activation='relu', padding='same'), #C6
    keras.layers.MaxPooling2D(pool_size=(2,2)), #S3
    keras.layers.Dropout(0.30),
    keras.layers.Flatten(), #Flatten    
    keras.layers.Dense(512, activation='relu'), #F1
    keras.layers.Dropout(0.7),
    keras.layers.Dense(10, activation='softmax') #Output layer
])

learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)
batch_size = 128
epochs = 30

lenet.summary()
lenet.compile(optimizer=optimizer, loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
hist = lenet.fit(x_train, y_train, epochs=epochs,batch_size = batch_size, validation_data=(x_test, y_test),verbose=1)
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title("Accuracy by LeNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss by LeNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
y_predictions= lenet.predict(x_test)
y_predictions.reshape(-1,)
y_predictions= np.argmax(y_predictions, axis=1)

confusion_matrix(y_test, y_predictions)
# confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()
print("Test accuracy:", accuracy_score(y_test, y_predictions))
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
# ...

# %% [markdown]
# **LeNet on MNIST Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")
(x_train, y_train), (x_test, y_test)  = keras.datasets.mnist.load_data()
classes = [str(i) for i in range(10)]
y_train = y_train.reshape(-1,)
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)
# Reshape and normalization
x_train = tf.image.resize(x_train[..., np.newaxis], (64, 64))
x_test = tf.image.resize(x_test[..., np.newaxis], (64, 64))
x_train = x_train / 255.0
x_test = x_test / 255.0

lenet = keras.models.Sequential([
    keras.layers.Conv2D(32, kernel_size=3, strides=1,  activation='relu', input_shape=(64,64,1), padding='same'), #C1
    keras.layers.Conv2D(32, kernel_size=3, strides=1,  activation='relu', padding='same'), #C2
    keras.layers.MaxPooling2D(pool_size=(2,2)), #S1
    keras.layers.Dropout(0.30),
    keras.layers.Conv2D(64, kernel_size=3, strides=1, activation='relu', padding='same'), #C3
    keras.layers.Conv2D(64, kernel_size=3, strides=1, activation='relu', padding='same'), #C4
    keras.layers.MaxPooling2D(pool_size=(2,2)), #S2
    keras.layers.Dropout(0.30),
    keras.layers.Flatten(), #Flatten    
    keras.layers.Dense(512, activation='relu'), #F1
    keras.layers.Dropout(0.7),
    keras.layers.Dense(10, activation='softmax') #Output layer
])

lenet.summary()
lenet.compile(optimizer='adam', loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
hist = lenet.fit(x_train, y_train, epochs=20,batch_size = 128, validation_data=(x_test, y_test),verbose=1)
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title("Accuracy by LeNet on MNIST Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss by LeNet on MNIST Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
y_predictions= lenet.predict(x_test)
y_predictions.reshape(-1,)
y_predictions= np.argmax(y_predictions, axis=1)

confusion_matrix(y_test, y_predictions)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_16 (Conv2D)          (None, 64, 64, 32)        320
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 32)        9248
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout_11 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 64)        18496
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_12 (Dropout)        (None, 16, 16, 64)        0
#
#  flatten_3 (Flatten)         (None, 16384)             0
#
#  dense_6 (Dense)             (None, 512)               8389120
#
#  dropout_13 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 10)                5130
#
# ...
# Total params: 8,459,242
# Trainable params: 8,459,242
# ...

# %% [markdown]
# Applied increase layer and to minit data in lenwt modal which gives high accuracy

# %%
# confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()
print("Test accuracy:", accuracy_score(y_test, y_predictions))
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
# Out:
# Test accuracy: 0.9933

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# Load the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Define the class labels
classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
           'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Resize the images to 64x64 and normalize the pixel values
x_train = tf.image.resize(x_train, (64, 64))
x_test = tf.image.resize(x_test, (64, 64))

y_train = keras.utils.to_categorical(y_train, num_classes=10)
y_test = keras.utils.to_categorical(y_test, num_classes=10)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape)
print(y_train.shape)

# Define the LeNet-5 model
lenet = keras.models.Sequential([
    keras.layers.Conv2D(32, kernel_size=3, strides=1,  activation='relu', input_shape=(64,64,1), padding='same'), #C1
    keras.layers.Conv2D(32, kernel_size=3, strides=1,  activation='relu', padding='same'), #C2
    keras.layers.MaxPooling2D(pool_size=(2,2)), #S1
    keras.layers.Dropout(0.30),
    keras.layers.Conv2D(64, kernel_size=3, strides=1, activation='relu', padding='same'), #C3
    keras.layers.Conv2D(64, kernel_size=3, strides=1, activation='relu', padding='same'), #C4
    keras.layers.MaxPooling2D(pool_size=(2,2)), #S2
    keras.layers.Dropout(0.30),
    keras.layers.Conv2D(128, kernel_size=3, strides=1, activation='relu', padding='same'), #C5
    keras.layers.Conv2D(128, kernel_size=3, strides=1, activation='relu', padding='same'), #C6
    keras.layers.MaxPooling2D(pool_size=(2,2)), #S3
    keras.layers.Dropout(0.30),
    keras.layers.Flatten(), #Flatten    
    keras.layers.Dense(512, activation='relu'), #F1
    keras.layers.Dropout(0.7),
    keras.layers.Dense(10, activation='softmax') #Output layer
])

# Set the learning rate, optimizer, batch size, and number of epochs
learning_rate = 0.001
optimizer = Adam(learning_rate=learning_rate)

epochs = 30

# Compile the model and train it on the training set
lenet.summary()
lenet.compile(optimizer=optimizer, loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
hist = lenet.fit(x_train, y_train, epochs=epochs, validation_data=(x_test, y_test), verbose=1)

# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title("Accuracy by LeNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss by LeNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
y_predictions= lenet.predict(x_test)
y_predictions.reshape(-1,)
y_predictions= np.argmax(y_predictions, axis=1)

confusion_matrix(y_test, y_predictions)
# confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()
print("Test accuracy:", accuracy_score(y_test, y_predictions))
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
# Out:
# (64, 64, 28)
# (60000, 10)
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_54 (Conv2D)          (None, 64, 64, 32)        320
#
#  conv2d_55 (Conv2D)          (None, 64, 64, 32)        9248
#
#  max_pooling2d_27 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  dropout_36 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_56 (Conv2D)          (None, 32, 32, 64)        18496
#
#  conv2d_57 (Conv2D)          (None, 32, 32, 64)        36928
#
#  max_pooling2d_28 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  dropout_37 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_58 (Conv2D)          (None, 16, 16, 128)       73856
#
#  conv2d_59 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d_29 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  dropout_38 (Dropout)        (None, 8, 8, 128)         0
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD, Adam
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
warnings.filterwarnings("ignore")


(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

y_train = y_train.reshape(-1,)
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)
# Reshape and normalization
x_train = tf.image.resize(x_train, (64, 64))
x_test = tf.image.resize(x_test, (64, 64))

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape)

#Define Alexnet Model
AlexNet =  Sequential()
AlexNet.add(Conv2D(filters=16, kernel_size=(3,3), strides=(4,4), input_shape=(64, 64, 3), activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(5,5),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Conv2D(60,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(30,(3,3),padding='same',activation='relu'))
AlexNet.add(Conv2D(20,(3,3),padding='same',activation='relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
AlexNet.add(Flatten())
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(200, activation='relu'))
AlexNet.add(Dropout(0.1))
AlexNet.add(Dense(10,activation='softmax'))

AlexNet.compile(optimizer='SGD', loss=keras.losses.sparse_categorical_crossentropy, metrics=['accuracy'])
AlexNet.summary()


history1 = AlexNet.fit(x_train , y_train , epochs=100, batch_size=128, validation_data=(x_test, y_test),verbose=1)
# Out:
# (50000, 64, 64, 3)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_10 (Conv2D)          (None, 16, 16, 16)        448
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 60)          24060
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 60)         0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 4, 4, 60)          32460
#
#  conv2d_13 (Conv2D)          (None, 4, 4, 30)          16230
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 20)          5420
#
#  max_pooling2d_8 (MaxPooling  (None, 2, 2, 20)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 80)                0
#
#  dense_6 (Dense)             (None, 200)               16200
#
#  dropout_4 (Dropout)         (None, 200)               0
#
#  dense_7 (Dense)             (None, 200)               40200
#
# ...
